# %% [markdown]
# # **(ADD THE NOTEBOOK NAME HERE)**

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %%
#Check Python version
! python --version
# Out:
# Python 3.12.8

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\jerem\\OneDrive\\Documents\\CodeInstitute\\vscode-projects\\Capstone_Evaluating_Domestic_Electrification_Measures\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir

# %% [markdown]
# # Section 1

# %% [markdown]
# Section 1 content

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = []
for c in range(1,199):
    for a in range(1, 16):
        for r in range(1, 5):
            row = [2500+2500*a, r*50,c]
            data.append(row)
        row = [2500+2500*a,238,c]
        data.append(row)
df = pd.DataFrame(data, columns=['Annual mileage','Nominal Range (miles)', 'Ecar Index'])
df['average daily mileage'] = df['Annual mileage']/365
df['Range2'] = df[['Nominal Range (miles)', 'average daily mileage']].max(axis=1)
df.head(60)
# Out:
#     Annual mileage  Nominal Range (miles)  Ecar Index  average daily mileage  \
# 0             5000                     50           1              13.698630
# 1             5000                    100           1              13.698630
# 2             5000                    150           1              13.698630
# 3             5000                    200           1              13.698630
# 4             5000                    238           1              13.698630
# 5             7500                     50           1              20.547945
# 6             7500                    100           1              20.547945
# 7             7500                    150           1              20.547945
# 8             7500                    200           1              20.547945
# 9             7500                    238           1              20.547945
# 10           10000                     50           1              27.397260
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
